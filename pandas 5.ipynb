# %%
import pandas as pd

# %%
df = pd.DataFrame({'col1':[1,2,3,4],'col2':[444,555,666,444],'col3':['abc','def','ghi','xyz']})
df
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df.head(2)
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def

# %%
df.tail(2)
# Out:
#    col1  col2 col3
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   col1    4 non-null      int64
#  1   col2    4 non-null      int64
#  2   col3    4 non-null      object
# dtypes: int64(2), object(1)
# memory usage: 228.0+ bytes

# %%
df
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df['col2'].unique()
# Out:
# array([444, 555, 666], dtype=int64)

# %%
df['col2'].nunique()
# Out:
# 3

# %%
df['col2'].value_counts()
# Out:
# col2
# 444    2
# 555    1
# 666    1
# Name: count, dtype: int64

# %%
df
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
newdf
# Out:
#    col1  col2 col3
# 1     2   555  def
# 2     3   666  ghi

# %%
newdf=df[(df['col1']>1) & (df['col2']>500)]

# %%
newdf
# Out:
#    col1  col2 col3
# 1     2   555  def
# 2     3   666  ghi

# %%
dir(newdf)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__arrow_c_stream__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__dataframe_consortium_standard__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
# ...

# %%
def times2(x):
    return x*2

# %%
df['col1'].apply(times2)
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# Name: col1, dtype: int64

# %%
df
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df['col3'].apply(len)
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# Name: col3, dtype: int64

# %%
df['col1'].sum()
# Out:
# 10

# %%
df
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
del df['col1']

# %%
df
# Out:
#    col2 col3
# 0   444  abc
# 1   555  def
# 2   666  ghi
# 3   444  xyz

# %%
df.columns
# Out:
# Index(['col2', 'col3'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
pf = pd.DataFrame({'col1':[1,2,3,4,5],'col2':[444,555,666,444,666],'col3':['abc','def','ghi','xyz','dfg']})
pf
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz
# 4     5   666  dfg

# %%
ni='1 3 5 7 9'.split()
ni
# Out:
# ['1', '3', '5', '7', '9']

# %%
pf['newindex']=ni

# %%
pf.set_index('newindex')
# Out:
#           col1  col2 col3
# newindex
# 1            1   444  abc
# 3            2   555  def
# 5            3   666  ghi
# 7            4   444  xyz
# 9            5   666  dfg

# %%
pf.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
pf = pd.DataFrame({'col1':[1,2,3,4,5],'col2':[444,555,666,444,666],'col3':['abc','def','ghi','xyz','dfg']},index=[10,20,30,40,50])
pf
# Out:
#     col1  col2 col3
# 10     1   444  abc
# 20     2   555  def
# 30     3   666  ghi
# 40     4   444  xyz
# 50     5   666  dfg

# %%
pf.index
# Out:
# Index([10, 20, 30, 40, 50], dtype='int64')

# %%
df.sort_values(by='col2')
# Out:
#    col2 col3
# 0   444  abc
# 3   444  xyz
# 1   555  def
# 2   666  ghi

# %%
df.isnull()
# Out:
#     col2   col3
# 0  False  False
# 1  False  False
# 2  False  False
# 3  False  False

# %%
df.dropna()
# Out:
#    col2 col3
# 0   444  abc
# 1   555  def
# 2   666  ghi
# 3   444  xyz

# %%
import numpy as np

# %%
df = pd.DataFrame({'col1':[1,2,3,np.nan],
                   'col2':[np.nan,555,666,444],
                   'col3':['abc','def','ghi','xyz']})
df.head()
# Out:
#    col1   col2 col3
# 0   1.0    NaN  abc
# 1   2.0  555.0  def
# 2   3.0  666.0  ghi
# 3   NaN  444.0  xyz

# %%
df.fillna('fill')
# Out:
#    col1   col2 col3
# 0   1.0   fill  abc
# 1   2.0  555.0  def
# 2   3.0  666.0  ghi
# 3  fill  444.0  xyz

# %%
data = {'A':['foo','foo','foo','bar','bar','bar'],
     'B':['one','one','two','two','one','one'],
       'C':['x','y','x','y','x','y'],
       'D':[1,3,2,5,4,1]}

df = pd.DataFrame(data)

# %%
df
# Out:
#      A    B  C  D
# 0  foo  one  x  1
# 1  foo  one  y  3
# 2  foo  two  x  2
# 3  bar  two  y  5
# 4  bar  one  x  4
# 5  bar  one  y  1

# %%
df.pivot_table(values='D',index=['B'],columns=['C'])
# Out:
# C      x    y
# B
# one  2.5  2.0
# two  2.0  5.0

# %%
pf = pd.DataFrame({'col1':[1,2,3,4,5],'col2':[444,555,666,444,np.nan],'col3':['abc','def','ghi','xyz','dfg']},index=[10,20,30,40,50])
pf
# Out:
#     col1   col2 col3
# 10     1  444.0  abc
# 20     2  555.0  def
# 30     3  666.0  ghi
# 40     4  444.0  xyz
# 50     5    NaN  dfg

# %%
pf.isnull()
# Out:
#      col1   col2   col3
# 10  False  False  False
# 20  False  False  False
# 30  False  False  False
# 40  False  False  False
# 50  False   True  False
