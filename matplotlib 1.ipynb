# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np
x = np.linspace(0, 5, 11)
y = x ** 2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y,'b')

# %%
plt.show()

# %%
plt.plot(x,y,y,x,'r')
# Out:
# [<matplotlib.lines.Line2D at 0x1a37c79f830>,
#  <matplotlib.lines.Line2D at 0x1a37c79f710>]

# %%
plt.show()

# %%
plt.plot(x,y,y,x,'r')
plt.xlabel('X Axis Title Here')
plt.ylabel('Y Axis Title Here')
plt.title('String Title Here');
plt.show()

# %%
plt.subplot(1,2,1)
plt.plot(x, y, 'r--')
plt.subplot(1,2,2)
plt.plot(y, x, 'b*-');
plt.show()

# %%
plt.subplot(2,1,1)
plt.plot(x, y, 'r--')
plt.subplot(2,1,2)
plt.plot(y, x, 'b*-');
plt.show()

# %%
plt.subplot(2,1,1)
plt.plot(x, y, 'r--')
plt.xlabel('X Axis Title Here')
plt.ylabel('Y Axis Title Here')
plt.title('String Title Here');

plt.subplot(2,1,2)
plt.plot(y, x, 'b*-');
plt.xlabel('X Axis Title Here')
plt.ylabel('Y Axis Title Here')
plt.title('String Title Here');
plt.show()
